# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Admin\Desktop\Datasets\1. Weather Data.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#first 10 rows
df.head(10)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# ...

# %%
#last 10 rows
df.tail(10)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8774  12/31/2012 14:00    -3.4              -5.7         84                6
# 8775  12/31/2012 15:00    -2.3              -4.6         84                9
# 8776  12/31/2012 16:00    -1.4              -4.0         82               13
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
# 8778  12/31/2012 18:00    -1.3              -3.1         88               17
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8774           11.3     100.57    Snow
# 8775            9.7     100.47    Snow
# ...

# %%
#columns in the dataset
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
#shape of the dataframe
df.shape
# Out:
# (8784, 8)

# %%
#info of the dataframe
df.info
# Out:
# <bound method DataFrame.info of              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Records when the weather was clear
Clear_weather=(df['Weather']== 'Clear')
print(Clear_weather)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather, Length: 8784, dtype: bool

# %%
#Total records when weather was clear
Records=Clear_weather.sum()
print(Records)
# Out:
# 1326

# %%
#Wind speed was 4km/hr
wind_speed=(df['Wind Speed_km/h']==4)
print(wind_speed)
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Wind Speed_km/h, Length: 8784, dtype: bool

# %%
#Total Number of times 
Number=wind_speed.sum()
print(Number)
# Out:
# 474

# %%
#finding missing value
df.isnull().sum()
# Out:
# Date/Time            0
# Temp_C               0
# Dew Point Temp_C     0
# Rel Hum_%            0
# Wind Speed_km/h      0
# Visibility_km        0
# Press_kPa            0
# Weather_Condition    0
# dtype: int64

# %%
#renaming coulumns
df=df.rename(columns={'Weather':'Weather_Condition'})

# %%
#calculate the mean visibility
mean_visibility=df['Visibility_km'].mean()
print(mean_visibility)
# Out:
# 27.664446721311478

# %%
#Find the number of records where the wind speed is greater than 24 km/hr and visibility is equal to 25 km
filtered_df=df[(df['Wind Speed_km/h']>24)&(df['Visibility_km']==25)]
print(filtered_df)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
#number of records
record_count=filtered_df.shape[0]
print(record_count)
# Out:
# 308

# %%
#mean value of each column for each weather condition
mean_values=df.groupby('Weather_Condition').mean(numeric_only=True)
print(mean_values)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather_Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
#Instances where the weather is clear and the relative humidity is greater than 50.
condition_1=(df['Weather_Condition']=='Mainly Clear') & (df['Rel Hum_%']>50)
print(condition_1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Length: 8784, dtype: bool

# %%
#visibility is above 40
condition_2=(df['Visibility_km']>40)
print(condition_2)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Visibility_km, Length: 8784, dtype: bool

# %%
#Applying the final condition to filter the dataframe
final_condition = condition_1 | condition_2
print(final_condition)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Length: 8784, dtype: bool

# %%
#filtered dataframe
df2=final_condition
df[final_condition]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 36      1/2/2012 12:00     1.7              -6.2         56               48
# 60      1/3/2012 12:00   -14.9             -22.6         52               20
# 61      1/3/2012 13:00   -15.1             -22.4         54               22
# 63      1/3/2012 15:00   -14.8             -22.2         53               19
# 64      1/3/2012 16:00   -15.3             -22.9         52               22
# ...                ...     ...               ...        ...              ...
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8754  12/30/2012 18:00   -12.6             -16.0         76               24
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8757  12/30/2012 21:00   -13.8             -16.5         80               20
# 8758  12/30/2012 22:00   -13.7             -16.3         81               19
#
# ...

# %%
#Total instances satisfying both conditions
instances=final_condition.sum()
print(instances)
# Out:
# 3127

# %%
#Number of weather conditions that include snow
Snow_conditions=df['Weather_Condition'].str.contains('Snow')
print(Snow_conditions)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8779     True
# 8780     True
# 8781     True
# 8782     True
# 8783     True
# Name: Weather_Condition, Length: 8784, dtype: bool

# %%
#count of number instances
Instances=Snow_conditions.sum()
print(Instances)
# Out:
# 583
